# %% [markdown]
# ### Using multiple data visualisations, identify how the retail industry has transformed and the key indicators for this change. Based on this, what will the industry look like in the next 5 years?

# %% [markdown]
# Layout of this notebook
#
# - Key definititons
# - Data wrangling and exploration
# - 1996 Data Visualisation
# - Dataset Visualisations
# - Analysis
# -

# %%
# Key definitions

# %% [markdown]
# ##### Code for the names:
#
# - Retail including automotive All = RIA
# - Retail including automotive Large Businesses = RIA_LB
# - Retail including automotive Small Businesses = RIA_SB
# - Retail excluding automotive All = REA
# - Retail excluding automotive Large Business = REA_LB
# - Retail excluding automotive Small Business = REA_SB
# - Predominantly Food Stores Total All = PFS
# - Predominantly Food Stores Large Business = PFS_LB
# - Predominantly Food Stores Small Business = PFS_SB
# - Non-Specialised Food Stores All = NSFS
# - Non-Specialised Food Stores Large Business = NSFS_LB
# - Non-Specialised Food Stores Small Business =  NSFS_SB
# - Specialist Food Stores = SFS
# - Alcoholic and Other beverages, and Tobacco = AaOBaT
# - Predominantly Non-food Stores Total All = PNFS
# - Predominantly Non-food Stores Total Large Business = PNFS_LB
# - Predominantly Non-food Stores Total Small Business = PNFS_SB
# - Non-Specialised Predominantly Non-food Stores All = NSPNFS
# - Non-Specialised Predominantly Non-food Stores Large Business = NSPNFS_LB
# - Non-Specialised Predominantly Non-food Stores Small Business = NSPNFS_SB
# - Textiles, Clothing, Footwear & Leather All = TCFL
# - Textiles, Clothing, Footwear & Leather Large Business = TCFL_LB
# - Textiles, Clothing, Footwear & Leather Small Business = TCFL_SB
# - Retail Sale of Textiles = RST
# - Retail Sale of Clothing All = RSC
# - Retail Sale of Clothing Large Business = RSC_LB
# - Retail Sale of Clothing Small Business = RSC_SB
# - Footwear & Leather Goods = FLG
# - Household Goods Stores = HGS
# - Household Goods Stores Large Business = HSG_LB
# - Household Goods Stores Small Business = HSG_SB
# - Furniture, Lighting = FL
# - Electrical Household Appliances = EHA
# - Hardware, Paint and Glass = HPG
# - Audio and video and music = AVaM
# - Other Non-food Stores = ONFS
# - Other Non-food Stores Large Business = ONFS_LB
# - Other Non-food Stores Small Business = ONFS_SB
# - Other Retail Pharmaceutical Medical = OR_PM
# - Other Retail Books Newspapers = OR_BN
# - Other Retail Floor Covering = OR_FC
# - Other Retail Computers and Telecommunications = OR_CT
# - Other Retail Specialised Stores NEC = OR_SSNEC
# - Non-store Retailing All = NSR
# - Non-store Retailing Large Business = NSR_LB
# - Non-store Retailing Small Business = NSR_SB
# - Non-store Mail Order Houses = NS_MOH
# - Non-store excluding Mail Order Houses = NS_EMOH
# - Automotive fuel = AF

# %%
# Data wrangling and exploration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style #importing the libraries

# %%
df = pd.read_csv("Total_monthly_sales.csv") #loading the dataset
df.head(3)
# Out:
#   Time Period All Retailing including automotive fuel - All Retailing  \
# 0     1986JAN                                                NaN
# 1     1986FEB                                                NaN
# 2     1986MAR                                                NaN
#
#   All Retailing including automotive fuel - Large Businesses  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   All Retailing including automotive fuel - Small Businesses  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   All Retailing excluding automotive fuel - All Retailing  \
# 0                                          9,415,792
# 1                                          7,279,178
# 2                                          9,562,899
#
# ...

# %%
#changing the columns titles so it is easier to understand
df.set_axis(["Month", "RIA", "RIA_LB", "RIA_SB", "REA", 
             "REA_LB", "REA_SB","PFS", "PFS_LB", "PFS_SB", 
             "NSFS", "NSFS_LB", "NSFS_SB", "SFS","AaOBaT", 
             "PNFS", "PNFS_LB", "PNFS_SB", "NSPNFS", "NSPNFS_LB",
             "NSPNFS_SB", "TCFL", "TCFL_LB", "TCFL_SB", "RST", 
             "RSC","RSC_LB", "RSC_SB", "FLG", "HGS", 
             "HGS_LB", "HGS_SB", "FL", "EHA", "HPG", 
             "AVaM", "ONFS","ONFS_LB", "ONFS_SB", "OR_PM", 
             "OR_BN", "OR_FC", "OR_CT", "OR_SSNEC","NSR", 
             "NSR_LB", "NSR_SB", "NS_MOH", "NS_EMOH", "AF"], axis="columns", inplace=True)

# %%
df.head(3) #displaying the new dataframe with the changed column titles
# Out:
#      Month  RIA RIA_LB RIA_SB        REA     REA_LB     REA_SB        PFS  \
# 0  1986JAN  NaN    NaN    NaN  9,415,792  5,406,797  4,008,986  3,737,172
# 1  1986FEB  NaN    NaN    NaN  7,279,178  4,156,194  3,122,988  3,092,640
# 2  1986MAR  NaN    NaN    NaN  9,562,899  5,517,794  4,045,120  3,985,511
#
#       PFS_LB     PFS_SB  ...    OR_BN    OR_FC    OR_CT OR_SSNEC      NSR  \
# 0  2,467,995  1,269,176  ...  224,555  160,035  235,310  654,936  805,445
# 1  2,036,219  1,056,428  ...  186,612  116,576  187,736  498,732  594,074
# 2  2,642,498  1,343,025  ...  241,925  141,235  244,805  691,884  763,192
#
#     NSR_LB   NSR_SB   NS_MOH  NS_EMOH   AF
# 0  413,051  392,390  563,860  241,585  NaN
# 1  291,432  302,645  398,622  195,452  NaN
# 2  372,125  391,064  515,472  247,720  NaN
#
# [3 rows x 50 columns]

# %%
df.info() #understand how the columns which have nan values and the data typ for all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 50 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      447 non-null    object
#  1   RIA        327 non-null    object
#  2   RIA_LB     327 non-null    object
#  3   RIA_SB     327 non-null    object
#  4   REA        447 non-null    object
#  5   REA_LB     447 non-null    object
#  6   REA_SB     447 non-null    object
#  7   PFS        447 non-null    object
#  8   PFS_LB     447 non-null    object
#  9   PFS_SB     447 non-null    object
#  10  NSFS       447 non-null    object
#  11  NSFS_LB    447 non-null    object
#  12  NSFS_SB    447 non-null    object
#  13  SFS        447 non-null    object
#  14  AaOBaT     447 non-null    object
#  15  PNFS       447 non-null    object
#  16  PNFS_LB    447 non-null    object
#  17  PNFS_SB    447 non-null    object
#  18  NSPNFS     447 non-null    object
# ...

# %%
# Getting rid of all the rows with Nan - which is 120 rows
df_new = df.dropna()
#df_new.head()

# %%
#Changing the datatype for all of the columns excluding the Month column
df1 = df_new.drop(['Month'], axis=1)

# %%
df1 = df1.replace(',','', regex=True)
df1.astype(str).astype(int)
# Out:
#           RIA    RIA_LB    RIA_SB       REA    REA_LB    REA_SB       PFS  \
# 120  17216871  11193667   6023221  15766943  10321570   5445386   6761551
# 121  14369116   9352081   5017022  13050509   8561413   4489086   5743640
# 122  18342578  11989200   6353371  16764685  11037181   5727496   7419730
# 123  15072263   9754502   5317762  13800351   8998353   4801998   5872909
# 124  14821129   9639583   5181554  13625221   8927611   4697622   5896876
# ..        ...       ...       ...       ...       ...       ...       ...
# 442  43401049  33919744   9481309  39123382  30322502   8800885  15182598
# 443  57830116  46409096  11421008  53016094  42371196  10644889  21243062
# 444  34930634  27046219   7884412  31239840  23954108   7285731  13666024
# 445  36373907  28058358   8315558  32585309  24879399   7705922  14655577
# 446  47221629  36443920  10777718  42520186  32514721  10005469  18859757
#
#        PFS_LB   PFS_SB      NSFS  ...   OR_BN   OR_FC   OR_CT  OR_SSNEC  \
# ...

# %%
df1.new = df1.apply(pd.to_numeric, errors='coerce')
# Out:
# <ipython-input-15-9bfce2e9c50d>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.new = df1.apply(pd.to_numeric, errors='coerce')

# %%
extracted_col = df["Month"]
display(extracted_col) #Joining the Month column back to the datatframe with the changed data types

df2 = df1.new.join(extracted_col)
df2.head()
# Out:
# 0      1986JAN
# 1      1986FEB
# 2      1986MAR
# 3      1986APR
# 4      1986MAY
#         ...
# 442    2022NOV
# 443    2022DEC
# 444    2023JAN
# 445    2023FEB
# 446    2023MAR
# Name: Month, Length: 447, dtype: object
#           RIA    RIA_LB   RIA_SB       REA    REA_LB   REA_SB      PFS  \
# 120  17216871  11193667  6023221  15766943  10321570  5445386  6761551
# 121  14369116   9352081  5017022  13050509   8561413  4489086  5743640
# 122  18342578  11989200  6353371  16764685  11037181  5727496  7419730
# 123  15072263   9754502  5317762  13800351   8998353  4801998  5872909
# 124  14821129   9639583  5181554  13625221   8927611  4697622  5896876
#
#       PFS_LB   PFS_SB     NSFS  ...   OR_FC   OR_CT  OR_SSNEC      NSR  \
# 120  5278231  1483320  5576326  ...  227555  418020   1215120   984892
# 121  4479731  1263909  4725504  ...  186396  334964   1015580   962010
# 122  5812068  1607659  6120735  ...  250525  426140   1381096  1077410
# ...

# %%
df2.dtypes #understanding the new data types
# Out:
# RIA           int64
# RIA_LB        int64
# RIA_SB        int64
# REA           int64
# REA_LB        int64
# REA_SB        int64
# PFS           int64
# PFS_LB        int64
# PFS_SB        int64
# NSFS          int64
# NSFS_LB       int64
# NSFS_SB       int64
# SFS           int64
# AaOBaT        int64
# PNFS          int64
# PNFS_LB       int64
# PNFS_SB       int64
# NSPNFS        int64
# NSPNFS_LB     int64
# NSPNFS_SB     int64
# TCFL          int64
# TCFL_LB       int64
# TCFL_SB       int64
# RST           int64
# RSC           int64
# RSC_LB        int64
# RSC_SB        int64
# FLG           int64
# HGS           int64
# HGS_LB        int64
# HGS_SB        int64
# FL            int64
# EHA           int64
# HPG           int64
# AVaM          int64
# ONFS          int64
# ONFS_LB       int64
# ONFS_SB       int64
# OR_PM         int64
# OR_BN         int64
# OR_FC         int64
# OR_CT         int64
# OR_SSNEC      int64
# NSR           int64
# NSR_LB        int64
# ...

# %%
df2 = df2.set_index('Month') #changing the axis to the month column
df2.head(2)
# Out:
#               RIA    RIA_LB   RIA_SB       REA    REA_LB   REA_SB      PFS  \
# Month
# 1996JAN  17216871  11193667  6023221  15766943  10321570  5445386  6761551
# 1996FEB  14369116   9352081  5017022  13050509   8561413  4489086  5743640
#
#           PFS_LB   PFS_SB     NSFS  ...   OR_BN   OR_FC   OR_CT  OR_SSNEC  \
# Month                               ...
# 1996JAN  5278231  1483320  5576326  ...  406490  227555  418020   1215120
# 1996FEB  4479731  1263909  4725504  ...  341112  186396  334964   1015580
#
#             NSR  NSR_LB  NSR_SB  NS_MOH  NS_EMOH       AF
# Month
# 1996JAN  984892  531494  453401  699327   285565  1449928
# 1996FEB  962010  574776  387232  722534   239476  1318607
#
# [2 rows x 49 columns]

# %% [markdown]
# #### The dataframe has undergone data wrangling and been removed of null values, duplicates and the format has changed. As the new dataframe has been created df2 will be used in the upcoming visudalisations.

# %%
#1996 Data Visualisation - which is the pilot

# %%
date96 = df2.iloc[:12] 
#getting the first years data to idenitfy common patterns and trends then expanding this to whole dataset

# %%
date96new = date96.iloc[:, [0,1,3,6,9, 13,14]]
date96new.head(3)
# Out:
#               RIA    RIA_LB       REA      PFS     NSFS  AaOBaT     PNFS
# Month
# 1996JAN  17216871  11193667  15766943  6761551  5576326  500170  8020500
# 1996FEB  14369116   9352081  13050509  5743640  4725504  430596  6344859
# 1996MAR  18342578  11989200  16764685  7419730  6120735  547910  8267545

# %%
date96new.reset_index(inplace=True)

# %%
date96v2 = date96new #this is the pilot study which will be replicated for the other years

# %%
date96v2.head()
# Out:
#      Month       RIA    RIA_LB       REA      PFS     NSFS  AaOBaT     PNFS
# 0  1996JAN  17216871  11193667  15766943  6761551  5576326  500170  8020500
# 1  1996FEB  14369116   9352081  13050509  5743640  4725504  430596  6344859
# 2  1996MAR  18342578  11989200  16764685  7419730  6120735  547910  8267545
# 3  1996APR  15072263   9754502  13800351  5872909  4829041  454736  7079523
# 4  1996MAY  14821129   9639583  13625221  5896876  4859356  452576  6922823

# %%
date96new['RIA'].plot(kind="bar", title="test", figsize=(10,8))


plt.style.use('ggplot')#styling that will be used and can be adjusted

plt.title("1996 Monthly breakdown of REA in thousands")
plt.xlabel("Month") #label the axis
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
ax1=date96v2.plot(kind='scatter', x='Month', y='RIA_LB', color='r', label='A')

#add scatter plot on same graph using B_assists vs. B_points
#ax2=df.plot(kind='scatter', x='B_assists', y='B_points', color='g', label='B', ax=ax1)

#specify x-axis and y-axis labels
ax1.set_xlabel('Assists') #label the axis
ax1.set_ylabel('Points')
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0, 0.5, 'Points')

# %%
x = date96new.index
y1 = date96new["RIA"]
y2 = date96new["REA"]
y3 = date96new["PFS"]

plt.figure(figsize=(10,8))
plt.style.use('bmh') #using the bmh style

plt.plot(x, y1, ls='solid', marker='+', lw=3, markersize=3) 
plt.plot(x, y2) #plotting each line and y value
plt.plot(x, y3) 
plt.title("RIA vs REA vs PFS Monthly breakdown in 1996")
plt.xticks(rotation = 45)#rotate the x axis
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(-2.0, 0, '−2'),
#   Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12')])

# %% [markdown]
# plot = date96new.plot.pie(y='RIA', figsize=(8, 8), autopct='%1.0f%%')

# %%
date96new.sum(axis = 0) #summing all columns
# Out:
# Month     1996JAN1996FEB1996MAR1996APR1996MAY1996JUN1996...
# RIA                                               205963231
# RIA_LB                                            135987987
# REA                                               189665406
# PFS                                                78809162
# NSFS                                               65019104
# AaOBaT                                              6007731
# PNFS                                               99206792
# dtype: object

# %%
date96new.loc['1996_Total']= date96new.sum()
date96new.tail(1) #summing all of the rows from the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                                                         Month        RIA  \
# 1996_Total  1996JAN1996FEB1996MAR1996APR1996MAY1996JUN1996...  205963231
#
#                RIA_LB        REA       PFS      NSFS   AaOBaT      PNFS
# 1996_Total  135987987  189665406  78809162  65019104  6007731  99206792

# %%
#Creating a new dataframe for the 1996 data so that they can all be joined and compared in the end

# %%
df96 = date96new.iloc[12:13]
df96
# Out:
#                                                         Month        RIA  \
# 1996_Total  1996JAN1996FEB1996MAR1996APR1996MAY1996JUN1996...  205963231
#
#                RIA_LB        REA       PFS      NSFS   AaOBaT      PNFS
# 1996_Total  135987987  189665406  78809162  65019104  6007731  99206792

# %% [markdown]
# ### Entire Dataset

# %% [markdown]
# ### 1996

# %%
#1996
df96_new = df2.iloc[:12] 

df96_new.loc['1996_Total']= df96_new.sum()

df1996 = df96_new.iloc[12:13]
df1996
#correct RIA is 205963231
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 1996_Total  205963231  135987987  69975242  189665406  126179461  63485943
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 1996_Total  78809162  61794075  17015087  65019104  ...  4808843  2591690
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 1996_Total  4968657  15762984  11649452  6704026  4945428  8436790  3212662
#
#                   AF
# Month
# 1996_Total  16297825
#
# ...

# %% [markdown]
# #### 1996 visualisations

# %%
ax = df1996[['RIA', 'REA', 'PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#specifying the columns that will be visualised

plt.style.use('ggplot') #add styling

plt.title(" 1996 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")#label the axis
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# The above graph includes 27 out of the 49 columns, with this data showing how the different categories are broken down, the columns in the graph excludes the scale of the business - as this detailed analysis will be conducted once the most inflential categories are identified.
#
# From the graph, it can be stated that subcategory which has the biggest impact on the retail industry excluding retail including and excluding automotive fuel is PNFS, PFS and NSFS.

# %%
df1996[['RIA_LB','RIA_SB']].plot(kind="bar", stacked = True, figsize=(7,7))
plt.style.use('bmh')

# %% [markdown]
# ### 1997

# %%
#1997
df97 = df2.iloc[12:24] 
#df97

# %%
#df97.sum()

# %%
df97.loc['1997_Total']= df97.sum()

df1997 = df97.iloc[12:13] #specify the year that is used and the row related to it

df1997
#right RIA is 21314997
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 1997_Total  213143997  144090912  69053087  195851719  133649670  62202050
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 1997_Total  81247427  64395818  16851603  67586243  ...  4917087  2720913
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 1997_Total  4738569  15676006  11529873  7045743  4484133  8417351  3112522
#
#                   AF
# Month
# 1997_Total  17292278
#
# ...

# %% [markdown]
# #### 1997 visualisations

# %%
ax = df1997[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#selecting the columns that will be analysed and visualised

plt.style.use('Solarize_Light2')

plt.title(" 1997 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 1998

# %%
#1998

df98 = df2.iloc[24:36] 
#df98

# %%
df98.loc['1998_Total']= df98.sum() #specify the year that is used and the row related to it


df1998 = df98.iloc[12:13]
df1998
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 1998_Total  220404608  151175570  69229028  202554874  140334331  62220537
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 1998_Total  85290723  68351815  16938912  71385572  ...  5288860  2128274
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 1998_Total  4805264  16706553  11607546  7661517  3946030  8693384  2914162
#
#                   AF
# Month
# 1998_Total  17849734
#
# ...

# %% [markdown]
# #### 1998 visualisations

# %%
ax = df1998[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#sselected the columns that will be analysed and visualised


plt.style.use('ggplot') #styling

plt.title(" 1999 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year") #label the axis
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 1999

# %%
#1999

df99 = df2.iloc[36:48] 
#df98
df99.loc['1999_Total']= df99.sum()

df1999 = df99.iloc[12:13] #specify the year that is used and the row related to it

df1999 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 1999_Total  227024642  158299985  68724657  208033736  146634834  61398902
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 1999_Total  88164479  70981246  17183234  74006469  ...  5291602  1927027
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 1999_Total  5203370  16956877  11489469  7941915  3547554  8911358  2578111
#
#                   AF
# Month
# 1999_Total  18990906
#
# ...

# %% [markdown]
# #### 1999 visualisations

# %%
ax = df1999[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('Solarize_Light2') #styling

plt.title(" 1997 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year") #label the axis
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 2000

# %%
#2000

df00 = df2.iloc[48:60] 
#df00

df00.loc['2000_Total']= df00.sum() #sum each column

df2000 = df00.iloc[12:13] ##specify the year that is used and the row related to it

df2000
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2000_Total  237864899  167482468  70382409  214888882  153288985  61599873
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 2000_Total  90663210  73045891  17617305  77133336  ...  5287134  1912129
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2000_Total  5301042  17582258  12044836  7964484  4080350  9290277  2754559
#
#                   AF
# Month
# 2000_Total  22976017
#
# ...

# %% [markdown]
# ### 2001

# %%
#2001

df01 = df2.iloc[60:72] 
#display(df01)

df01.loc['2001_Total']= df01.sum() 

df2001 = df01.iloc[12:13]#specify the year that is used and the row related to it

df2001
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2001_Total  248311974  177145353  71166617  226460225  163483762  62976461
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 2001_Total  95699672  77521488  18178187  82323994  ...  5158247  1963313
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2001_Total  5331829  19098789  11573174  7459043  4114131  8976906  2596268
#
#                   AF
# Month
# 2001_Total  21851749
#
# ...

# %% [markdown]
# ### 2002

# %%
#2002

df02 = df2.iloc[72:84] 
#display(df02)

df02.loc['2002_Total']= df02.sum() # sum and specify the year that is used and the row related to it

df2002 = df02.iloc[12:13] 
df2002 #display dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2002_Total  263302576  189670669  73631915  241474847  175903316  65571537
#
#                   PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                                ...
# 2002_Total  101559287  83045688  18513599  88387484  ...  5704825  2289384
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2002_Total  6081948  20845552  12053905  7402780  4651126  9037699  3016206
#
#                   AF
# Month
# 2002_Total  21827729
#
# ...

# %% [markdown]
# ### 2003

# %%
#2003

df03 = df2.iloc[84:96] 
#display(df03)

df03.loc['2003_Total']= df03.sum() #specify the year that is used and the row related to it

df2003 = df03.iloc[12:13]
df2003 #display dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2003_Total  265334840  195608640  69726198  241759331  180681854  61077476
#
#                   PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                                ...
# 2003_Total  103389624  85571461  17818165  91139869  ...  5347630  2102623
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2003_Total  5443117  21718053  10791089  7426488  3364601  8292250  2498839
#
#                   AF
# Month
# 2003_Total  23575509
#
# ...

# %% [markdown]
# ### 2004

# %%
#2004

df04 = df2.iloc[96:108] 
#display(df04)

df04.loc['2004_Total']= df04.sum() #specify the year that is used and the row related to it


df2004 = df04.iloc[12:13]
df2004 #display dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2004_Total  277849341  205699531  72149808  252952167  189634683  63317480
#
#                   PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                                ...
# 2004_Total  107517299  89295935  18221359  95572987  ...  5495234  2213223
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2004_Total  6908742  22481138  11910764  7924694  3986070  9191519  2719245
#
#                   AF
# Month
# 2004_Total  24897174
#
# ...

# %% [markdown]
# ### 2005

# %%
#2005

df05 = df2.iloc[108:120] 
#display(df05)

df05.loc['2005_Total']= df05.sum() #specify the year that is used and the row related to it


df2005 = df05.iloc[12:13]
df2005 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2005_Total  281450387  209669075  71781316  255685805  192629283  63056525
#
#                   PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                                ...
# 2005_Total  110993041  92822291  18170757  99297297  ...  5519123  2194765
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2005_Total  7218269  22260329  11886053  7454239  4431812  9424919  2461134
#
#                   AF
# Month
# 2005_Total  25764582
#
# ...

# %% [markdown]
# ### 2006

# %%
#2006

df06 = df2.iloc[120:132] 
#display(df06)

df06.loc['2006_Total']= df06.sum() #specify the year that is used and the row related to it


df2006 = df06.iloc[12:13]
df2006 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2006_Total  292109661  219416840  72692829  261983455  199316008  62667457
#
#                   PFS    PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                 ...
# 2006_Total  114997761  96216171  18781600  103456951  ...  4975202  2418424
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH  \
# Month
# 2006_Total  6511409  22963498  12141587  7610452  4531135  9665171  2476416
#
#                   AF
# Month
# 2006_Total  30126206
# ...

# %% [markdown]
# ### 2007

# %%
#2007

df07 = df2.iloc[132:144] 
#display(df07)

df07.loc['2007_Total']= df07.sum() #specify the year that is used and the row related to it


df2007 = df07.iloc[12:13]
df2007 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2007_Total  303621212  230046019  73575179  271352215  208124168  63228034
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2007_Total  119826797  101159160  18667629  108665215  ...  4645637  2687384
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2007_Total  5907117  24365206  12648665  8194908  4453753  10392756  2255909
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2008

# %%
#2008

df08 = df2.iloc[144:156] 
#display(df08)

df08.loc['2008_Total']= df08.sum() #specify the year that is used and the row related to it


df2008 = df08.iloc[12:13]
df2008 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2008_Total  321177892  245670675  75507247  285072063  218491247  66580843
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2008_Total  129162128  108741505  20420642  117264613  ...  4477022  2486939
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2008_Total  5680563  27601744  13760890  8591618  5169273  11091017  2669873
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2009

# %%
#2009

df09 = df2.iloc[156:168] 
#display(df09)

df09.loc['2009_Total']= df09.sum() #specify the year that is used and the row related to it


df2009 = df09.iloc[12:13]
df2009 #display the dataframe
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2009_Total  317657969  245248597  72409375  285273313  220138332  65134982
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2009_Total  133632728  113001496  20631227  122147915  ...  4708885  2513546
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2009_Total  5070771  26160319  14386018  9055033  5330986  11538552  2847466
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2010

# %%
#2010

df10 = df2.iloc[168:180] 
#display(df10)

df10.loc['2010_Total']= df10.sum()# sum and specify the year that is used and the row related to it


df2010 = df10.iloc[12:13]
df2010
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2010_Total  326241653  256803080  69438573  292348102  229263941  63084162
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2010_Total  135750233  116704393  19045843  125301829  ...  4305379  2071237
#
#               OR_CT  OR_SSNEC       NSR   NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2010_Total  4739522  28067119  15914920  9623846  6291077  13040242  2874678
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2011

# %%
#2011

df11 = df2.iloc[180:192] 
#display(df11)

df11.loc['2011_Total']= df11.sum() #sum and specify the year that is used and the row related to it

df2011 = df11.iloc[12:13]
df2011
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2011_Total  343158857  270358949  72799911  302770198  237638837  65131361
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2011_Total  141678981  121279664  20399315  130832767  ...  4392492  1612980
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2011_Total  4736625  28541875  18280079  10973084  7306997  15322032  2958047
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2012

# %%
#2012 

df12 = df2.iloc[192:204] 
#display(df12)

df12.loc['2012_Total']= df12.sum() #sum and specify the year that is selected

df2012 = df12.iloc[12:13]
df2012
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2012_Total  351048767  277656503  73392252  310757067  244928638  65828417
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2012_Total  145660447  125371536  20288901  135043944  ...  4270353  2079617
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2012_Total  4294878  28764535  20043107  12530998  7512109  17275700  2767407
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2013

# %%
#2013 looking at the data from this year

df13 = df2.iloc[204:216] 
#display(df13)

df13.loc['2013_Total']= df13.sum() #sum and specify the year that is used and the row related to it

df2013 = df13.iloc[12:13]
df2013
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2013_Total  360107179  285729717  74377457  321054734  254021087  67033640
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2013_Total  150013642  129763465  20250174  139136937  ...  3993328  2380953
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2013_Total  4472831  29383183  23409315  14542726  8866590  20275510  3133805
#
#                   AF
# Month
# ...

# %% [markdown]
# ### 2014

# %%
#2014 looking at the data from this year through visualisations

df14 = df2.iloc[216:228] 
#display(df14)

df14.loc['2014_Total']= df14.sum() #sum and specify the year that is used and the row related to it

df2014 = df14.iloc[12:13]
df2014
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2014_Total  378053188  298505896  79547288  339724291  267828046  71896241
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2014_Total  154559473  133952581  20606883  143457270  ...  3820650  2306127
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2014_Total  4682368  33233529  26581641  16246277  10335362  23860878
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# ### 2015

# %%
#2015 looking at the data from this year

df15 = df2.iloc[228:240] 
#display(df15)

df15.loc['2015_Total']= df15.sum() #sum and specify the year that is used and the row related to it


df2015 = df15.iloc[12:13]
df2015
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2015_Total  374817465  297903920  76913545  339445522  269017176  70428348
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2015_Total  151742476  131439338  20303141  140431989  ...  3923042  1631561
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB   NSR_SB    NS_MOH  NS_EMOH  \
# Month
# 2015_Total  5159906  31821500  28469085  18622894  9846190  26158299  2310786
#
#                   AF
# Month
# ...

# %% [markdown]
# #### 2015 Visualisation

# %%
ax = df2015[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('Solarize_Light2')#using the styling for the plot

plt.title("2015 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")#label the axis
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# Similar to the years prior, PNFS, was the subcategory which affected the retail industry the most - that was then followed by PFS and NSFS. The least influential categories were RST at a value of 744605, that was then followed by AVaM and OR_FC.

# %% [markdown]
# ### 2016

# %%
df16 = df2.iloc[240:252] 
#display(df16)

df16.loc['2016_Total']= df16.sum() #sum and specify the year that is used and the row related to it

df2016 = df16.iloc[12:13]
df2016

# %% [markdown]
# #### 2016 Visualisation

# %%
ax = df2016[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('ggplot') #styling used

plt.title("2016 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year") #add labels 
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 2017

# %%
#2017

df17 = df2.iloc[252:264] 
#display(df17)

df17.loc['2017_Total']= df17.sum() #sum and specify the year that is used and the row related to it

df2017 = df17.iloc[12:13]
df2017
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2017_Total  405780927  319261803  86519119  366086227  286503038  79583185
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2017_Total  158112817  137077164  21035654  147199779  ...  3675722  1790980
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2017_Total  5103228  35608234  39038759  24600565  14438196  36790004
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# #### 2017 Visualisations

# %%
ax = df2017[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('Solarize_Light2') #styling

plt.title("2017 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 2018

# %%
#2018

df18 = df2.iloc[264:276] 
#display(df18)

df18.loc['2018_Total']= df18.sum()

df2018 = df18.iloc[12:13] #specify the year that is used and the row related to it

df2018
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2018_Total  423709363  331655864  92053498  380702362  295807110  84895252
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2018_Total  163289374  141690476  21598904  151699661  ...  3809132  1809224
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2018_Total  4765089  36792891  43534390  26457562  17076825  41155689
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# #### 2018 Visualisations

# %%
ax = df2018[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#select the columns to visualise

plt.style.use('ggplot') #add styling

plt.title("2018 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year") #add labels
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 2019

# %%
df19 = df2.iloc[276:288] 
#display(df19)

df19.loc['2019_Total']= df19.sum()

df2019 = df19.iloc[12:13] #specify the year that is used and the row related to it

df2019
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2019_Total  439600484  343833770  95766714  393738820  305328275  88410545
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2019_Total  167730384  145102774  22627610  154995538  ...  3701477  1525750
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2019_Total  4691416  39255162  49951682  31281410  18670272  47392480
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# #### 2019 Visualisations

# %%
ax = df2019[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#the columns that will be visualised and analysed

plt.style.use('Solarize_Light2') #add styling

plt.title("2019 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year") #add labels
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### 2020

# %%
#2020

df20 = df2.iloc[288:300] 
#display(df20)

df20.loc['2020_Total']= df20.sum()

df2020 = df20.iloc[12:13] #specify the year that is used and the row related to it

df2020
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2020_Total  436741512  336892329  99849186  402918458  308721742  94196717
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2020_Total  179369698  155817460  23552236  167420355  ...  3190049  1337829
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2020_Total  3147870  36456850  66097849  41122268  24975582  63326491
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# #### 2020 Visualisations

# %%
ax = df2020[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('ggplot') #add styling

plt.title("2020 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")#add axis labels
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# Up until 2020, the trend of PNFS being the highest valued category and therefore the most influential altered as PFS then became the most infelutnial.
#
# This is followed by NSFS and then PNFS. A reason for this change may be due to the context of this year, whereby the coronavirus was in full effect, with supermarkets and food stores being some of the few shops which were allowed to remain open. Predominantly Food Stores can be broken down into 2 further categories which will be displayed below:

# %% [markdown]
# ### 2021

# %%
#2021

df21 = df2.iloc[300:312] 
#display(df21)

df21.loc['2021_Total']= df21.sum()

df2021 = df21.iloc[12:13] #specify the year that is used and the row related to it

df2021
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB     RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 2021_Total  464163552  357312545  106851022  421321019  321502437  99818593
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2021_Total  179131182  153759937  25371251  165453294  ...  2849446  1976372
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2021_Total  3411246  42689084  68541618  43801225  24740397  65325103
#
#             NS_EMOH        AF
# Month
# ...

# %% [markdown]
# #### 2021 Visualisations

# %%
ax = df2021[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('Solarize_Light2') #add styling

plt.title("2021 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# The new pattern continues, where PFS is the most influential category; but the ones which do not have as much of an affect consist of ONFS, AVaM and OR_FC. It seems as though these have not changed from 1996.

# %% [markdown]
# ### 2022

# %%
#2022

df22 = df2.iloc[312:324] 
#display(df22)

df22.loc['2022_Total']= df22.sum()

df2022 = df22.iloc[12:13]
df2022
# Out:
# /Users/rhiannahepburn/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#                   RIA     RIA_LB     RIA_SB        REA     REA_LB     REA_SB  \
# Month
# 2022_Total  495667433  385294645  110372789  440907055  339373716  101533339
#
#                   PFS     PFS_LB    PFS_SB       NSFS  ...    OR_BN    OR_FC  \
# Month                                                  ...
# 2022_Total  185629898  158780132  26849766  170847836  ...  3328302  2749906
#
#               OR_CT  OR_SSNEC       NSR    NSR_LB    NSR_SB    NS_MOH  \
# Month
# 2022_Total  4084416  45698178  64965303  43586955  21378349  61780059
#
#             NS_EMOH        AF
# Month
# ...

# %%
#df2022[['AVaM', 'RST','OR_FC','NS_EMOH']]

# %%
3185244-2749906
# Out:
# 435338

# %% [markdown]
# #### 2022 Visualisations

# %%
ax = df2022[['PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('ggplot')

plt.title("2022 Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# As some sense of normality seems occur again, the pattern reverts to its old way where PNFS is the leading subcategory.

# %% [markdown]
# ### 2023

# %%
#2023

df23 = df2.iloc[324:] 
display(df23)

df23.loc['2023_Total']= df23.sum()

df2023 = df23.iloc[12:13]
df2023
# Out:
#               RIA    RIA_LB    RIA_SB       REA    REA_LB    REA_SB       PFS  \
# Month
# 2023JAN  34930634  27046219   7884412  31239840  23954108   7285731  13666024
# 2023FEB  36373907  28058358   8315558  32585309  24879399   7705922  14655577
# 2023MAR  47221629  36443920  10777718  42520186  32514721  10005469  18859757
#
#            PFS_LB   PFS_SB      NSFS  ...   OR_BN   OR_FC   OR_CT  OR_SSNEC  \
# Month                                 ...
# 2023JAN  11674383  1991642  12577565  ...  220705  210884  326686   2625905
# 2023FEB  12478502  2177080  13410085  ...  246087  208560  266827   3093569
# 2023MAR  16118407  2741356  17301868  ...  297792  268127  313916   4201714
#
#              NSR   NSR_LB   NSR_SB   NS_MOH  NS_EMOH       AF
# Month
# 2023JAN  4770877  3070696  1700180  4564761   206116  3690794
# 2023FEB  4739785  3049827  1689958  4523272   216513  3788598
# 2023MAR  6231000  4052730  2178271  5927212   303788  4701443
#
# [3 rows x 49 columns]
# ...

# %% [markdown]
# #### Individual Analysis

# %%
df2
# Out:
#               RIA    RIA_LB    RIA_SB       REA    REA_LB    REA_SB       PFS  \
# Month
# 1996JAN  17216871  11193667   6023221  15766943  10321570   5445386   6761551
# 1996FEB  14369116   9352081   5017022  13050509   8561413   4489086   5743640
# 1996MAR  18342578  11989200   6353371  16764685  11037181   5727496   7419730
# 1996APR  15072263   9754502   5317762  13800351   8998353   4801998   5872909
# 1996MAY  14821129   9639583   5181554  13625221   8927611   4697622   5896876
# ...           ...       ...       ...       ...       ...       ...       ...
# 2022NOV  43401049  33919744   9481309  39123382  30322502   8800885  15182598
# 2022DEC  57830116  46409096  11421008  53016094  42371196  10644889  21243062
# 2023JAN  34930634  27046219   7884412  31239840  23954108   7285731  13666024
# 2023FEB  36373907  28058358   8315558  32585309  24879399   7705922  14655577
# 2023MAR  47221629  36443920  10777718  42520186  32514721  10005469  18859757
#
# ...

# %% [markdown]
# #### Joining all Datasets

# %%
df_row = pd.concat([df1996, df1997, df1998, df1999,
                   df2000, df2001, df2002, df2003,
                   df2004, df2005, df2006, df2007, 
                   df2008, df2009, df2010, df2011,
                    df2012, df2013, df2014, df2015,
                    df2016, df2017, df2018, df2019,
                    df2020, df2021, df2022])

df_row #joining and merging all of the datasets
# Out:
#                   RIA     RIA_LB     RIA_SB        REA     REA_LB     REA_SB  \
# Month
# 1996_Total  205963231  135987987   69975242  189665406  126179461   63485943
# 1997_Total  213143997  144090912   69053087  195851719  133649670   62202050
# 1998_Total  220404608  151175570   69229028  202554874  140334331   62220537
# 1999_Total  227024642  158299985   68724657  208033736  146634834   61398902
# 2000_Total  237864899  167482468   70382409  214888882  153288985   61599873
# 2001_Total  248311974  177145353   71166617  226460225  163483762   62976461
# 2002_Total  263302576  189670669   73631915  241474847  175903316   65571537
# 2003_Total  265334840  195608640   69726198  241759331  180681854   61077476
# 2004_Total  277849341  205699531   72149808  252952167  189634683   63317480
# 2005_Total  281450387  209669075   71781316  255685805  192629283   63056525
# 2006_Total  292109661  219416840   72692829  261983455  199316008   62667457
# ...

# %%
df_row.head()
# Out:
#                   RIA     RIA_LB    RIA_SB        REA     REA_LB    REA_SB  \
# Month
# 1996_Total  205963231  135987987  69975242  189665406  126179461  63485943
# 1997_Total  213143997  144090912  69053087  195851719  133649670  62202050
# 1998_Total  220404608  151175570  69229028  202554874  140334331  62220537
# 1999_Total  227024642  158299985  68724657  208033736  146634834  61398902
# 2000_Total  237864899  167482468  70382409  214888882  153288985  61599873
#
#                  PFS    PFS_LB    PFS_SB      NSFS  ...    OR_BN    OR_FC  \
# Month                                               ...
# 1996_Total  78809162  61794075  17015087  65019104  ...  4808843  2591690
# 1997_Total  81247427  64395818  16851603  67586243  ...  4917087  2720913
# 1998_Total  85290723  68351815  16938912  71385572  ...  5288860  2128274
# 1999_Total  88164479  70981246  17183234  74006469  ...  5291602  1927027
# 2000_Total  90663210  73045891  17617305  77133336  ...  5287134  1912129
#
# ...

# %%
#df_row[['AVaM', 'RST','OR_FC','NS_EMOH']]

# %%
df_row.sum() #sum of each column
# Out:
# RIA          8862003697
# RIA_LB       6742490039
# RIA_SB       2119513646
# REA          7995628837
# REA_LB       6083900590
# REA_SB       1911728226
# PFS          3508067452
# PFS_LB       2968832151
# PFS_SB        539235297
# NSFS         3177715705
# NSFS_LB      2886468895
# NSFS_SB       291246744
# SFS           212007213
# AaOBaT        118344534
# PNFS         3820058329
# PNFS_LB      2691590183
# PNFS_SB      1128468120
# NSPNFS        717270708
# NSPNFS_LB     649088378
# NSPNFS_SB      68182328
# TCFL         1042564398
# TCFL_LB       884189814
# TCFL_SB       158374602
# RST            23139620
# RSC           909424144
# RSC_LB        795444475
# RSC_SB        113979677
# FLG           110000634
# HGS           869918412
# HGS_LB        584915996
# HGS_SB        285002396
# FL            315037750
# EHA           215102559
# HPG           292586014
# AVaM           47192089
# ONFS         1190304811
# ONFS_LB       573396020
# ONFS_SB       616908791
# ...

# %%
8855383663-865233688
# Out:
# 7990149975

# %%
3505193696-865233688
# Out:
# 2639960008

# %%
#df_row.dtypes

# %% [markdown]
# df_row.index

# %% [markdown]
# ## Entire Dataset visualisations

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))

data=df_row[['RIA', 'REA',
            'PFS', 'NSFS',
             'TCFL', 'NSPNFS'
        ]]
sns.set_style("darkgrid")
sns.kdeplot(data=data).set(title='RIA, REA, PFS, NSFS, TCFL, NSPNFS - KDE Diagram')

#'RST'
# Out:
# [Text(0.5, 1.0, 'RIA, REA, PFS, NSFS, TCFL, NSPNFS - KDE Diagram')]

# %%
plt.figure(figsize=(20,10))
sns.color_palette("husl", 8)

data=df_row[['SFS','NS_EMOH',
        'AaOBaT', 'FLG', 'OR_FC'
        ]]

sns.set_style("darkgrid")
sns.kdeplot(data=data).set(title='SFS, NS_EMOH, AaOBaT, FLG, OR_FC - KDE Diagram')

sns.kdeplot(data=data)

#PNFS , 'OR_CT', 'OR_SSNEC', 'AVaM','HGS',
# Out:
# <Axes: title={'center': 'SFS, NS_EMOH, AaOBaT, FLG, OR_FC - KDE Diagram'}, ylabel='Density'>

# %%
plt.figure(figsize=(20,10))

data=df_row[['OR_CT',  'AVaM','HGS', 'OR_BN']]

sns.set_style("darkgrid")
sns.kdeplot(data=data).set(title='OR_CT, AVaM, HGS, OR_BN - KDE Diagram')
#KDE plot of each category

sns.kdeplot(data=data)
# Out:
# <Axes: title={'center': 'OR_CT, AVaM, HGS, OR_BN - KDE Diagram'}, ylabel='Density'>

# %%
plt.figure(figsize=(20,10))

data=df_row[['NSR', 'NS_MOH','AF', 'ONFS', 'OR_SSNEC','PNFS' 
        ]]

sns.set_style("darkgrid")
sns.kdeplot(data=data).set(title='NSR, NS_MOH, AF, ONFS, OR_SSNEC & PNFS - KDE Diagram')

sns.kdeplot(data=data)
# Out:
# <Axes: title={'center': 'NSR, NS_MOH, AF, ONFS, OR_SSNEC & PNFS - KDE Diagram'}, ylabel='Density'>

# %%
plt.figure(figsize=(20,10))

data=df_row[[  'FL', 'EHA', 
        'HPG',   'OR_PM']]

sns.set_style("darkgrid")
sns.kdeplot(data=data).set(title='FL, EHA, HPG & OR_PM - KDE Diagram')

sns.kdeplot(data=data)
# Out:
# <Axes: title={'center': 'FL, EHA, HPG & OR_PM - KDE Diagram'}, ylabel='Density'>

# %%
df_row[['RIA', 'REA', 'PFS', 'NSFS', 'SFS',
        'AaOBaT', 'PNFS', 'NSPNFS', 'TCFL', 'RST',
        'RSC', 'FLG', 'HGS', 'FL', 'EHA', 
        'HPG', 'AVaM', 'ONFS', 'OR_PM', 'OR_BN',
        'OR_FC', 'OR_CT', 'OR_SSNEC', 'NSR', 'NS_MOH',
        'NS_EMOH', 'AF'
       ]].plot(kind="bar", title="test", figsize=(30,15))


plt.style.use('ggplot')

plt.title(" Annual breakdown of the features which affect the Retail industry", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %% [markdown]
# ### RIA

# %%
#df_row['RIA']

# %%
df_row['RIA'].plot(kind="bar", title="test", figsize=(12,10))
#looking at the specific column and visualising the annual breakdown

plt.style.use('ggplot')

plt.title(" Annual breakdown of RIA")
plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
import plotly.express as px
df = df_row['RIA']
x = df_row.index
fig = px.histogram(df,x=x,
                   marginal="box")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-576053d09a82> in <module>
#       1 import plotly.express as px
# ----> 2 df = df_row['RIA']
#       3 x = df_row.index
#       4 fig = px.histogram(df,x=x,
#       5                    marginal="box")
#
# NameError: name 'df_row' is not defined

# %% [markdown]
# ### REA

# %%
df_row['REA'].plot(kind="bar", title="test", figsize=(12,10))
#looking at the specific column and visualising the annual breakdown

plt.style.use('fivethirtyeight')

plt.title(" Annual breakdown of REA")
plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %% [markdown]
# ### PFS

# %%
df_row['PFS'].sum()
# Out:
# 3508067452

# %%
df_row['PNFS'].sum()
# Out:
# 3820058329

# %%
3508067452+3820058329
# Out:
# 7328125781

# %%
df_row[['PFS', 'PNFS'
       ]].plot(kind="bar", title="test", figsize=(30,15))
#looking at the specific columns and visualising the annual breakdown

plt.style.use('ggplot')

plt.title(" Annual breakdown PFS vs PNFS", fontsize=32)
plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
df_row['PFS'].plot(kind="bar", title="test", figsize=(12,10))


plt.style.use('Solarize_Light2')

plt.title(" Annual breakdown of PFS")
plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
plot = df_row.plot.pie(y='PFS', figsize=(10, 10), 
                       autopct='%1.0f%%')

# %%
df_row[['PFS_LB','PFS_SB']].plot(kind="bar", title="test",stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'test'}, xlabel='Month'>

# %% [markdown]
# ### NSFS

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row['NSFS'], x=x, y="NSFS")
fig.show()
# Out:
# <div>                            <div id="beb1f42e-cf39-4226-b237-12e7a9385b06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beb1f42e-cf39-4226-b237-12e7a9385b06")) {                    Plotly.newPlot(                        "beb1f42e-cf39-4226-b237-12e7a9385b06",                        [{"hovertemplate":"Month=%{x}<br>NSFS=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","20
# ...

# %%
import plotly.express as px
data = df_row[['NSFS_LB','NSFS_SB']]
fig = px.box(data, points="all") #comparing the businesses scale
fig.show()
# Out:
# <div>                            <div id="52273422-bf26-4315-a03a-84e9434fdfdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52273422-bf26-4315-a03a-84e9434fdfdd")) {                    Plotly.newPlot(                        "52273422-bf26-4315-a03a-84e9434fdfdd",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","NSFS_LB","N
# ...

# %%
df_row[['NSFS_LB','NSFS_SB']].plot(kind="box", 
                                title="test", figsize=(12,10))
# Out:
# <Axes: title={'center': 'test'}>

# %% [markdown]
# ### SFS

# %%
#df_row['SFS']

# %%
df_row['SFS'].plot(kind="bar", title="Annual breakdown of SFS", figsize=(8,8))
#looking at the specific column and visualising the annual breakdown

plt.style.use('ggplot')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %% [markdown]
# ### AaOBaT

# %%
#df_row['AaOBaT']

# %%
df_row['AaOBaT'].plot(kind="bar", title="Annual breakdown of SFS", figsize=(12,10))
#looking at the specific column and visualising the annual breakdown

plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %% [markdown]
# ### PNFS

# %%
df_row['PNFS'].plot(kind="line", title="Annual breakdown of PNFS", figsize=(12,10))
#looking at the specific column and visualising the annual breakdown

plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
df_row[['PNFS_LB','PNFS_SB']].plot(kind="bar", 
                                 title="PNFS Scale",
                                   stacked = True, figsize=(12,10))
#scale breakdown in the form of a stacked bar chart
# Out:
# <Axes: title={'center': 'PNFS Scale'}, xlabel='Month'>

# %% [markdown]
# ### NSPNFS

# %%
df_row['NSPNFS'].plot(kind="line", title="Annual breakdown of NSPNFS", figsize=(12,10))
#looking at the specific column and visualising the annual breakdown

plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
df_row[['NSPNFS_LB','NSPNFS_SB']].plot(kind="bar", 
                                 title="NSPNFS Scale",
                                   stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'NSPNFS Scale'}, xlabel='Month'>

# %% [markdown]
# ### TCFL

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row['TCFL'], x=x, y="TCFL")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="8d88d3cc-553c-46b8-91fc-ab0ea3779439" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d88d3cc-553c-46b8-91fc-ab0ea3779439")) {                    Plotly.newPlot(                        "8d88d3cc-553c-46b8-91fc-ab0ea3779439",                        [{"hovertemplate":"Month=%{x}<br>TCFL=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","20
# ...

# %%
df_row[['TCFL_LB','TCFL_SB']].plot(kind="bar", 
                                 title="TCFL Scale",
                                   stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'TCFL Scale'}, xlabel='Month'>

# %% [markdown]
# ### RST

# %%
plot = df_row.plot.pie(y='RST', figsize=(10, 10), 
                       autopct='%1.0f%%')
#piechart breaking down RST

# %% [markdown]
# ### RSC

# %%
df_row['RSC']
# Out:
# Month
# 1996_Total    20991859
# 1997_Total    22005813
# 1998_Total    22325933
# 1999_Total    22856089
# 2000_Total    24083079
# 2001_Total    26334868
# 2002_Total    28391631
# 2003_Total    28807302
# 2004_Total    30363769
# 2005_Total    30699537
# 2006_Total    32497759
# 2007_Total    33314465
# 2008_Total    33989508
# 2009_Total    33722784
# 2010_Total    35471988
# 2011_Total    37038088
# 2012_Total    37534328
# 2013_Total    38630971
# 2014_Total    40948274
# 2015_Total    41370268
# 2016_Total    40105643
# 2017_Total    42765303
# 2018_Total    43452305
# 2019_Total    44171704
# 2020_Total    33158038
# 2021_Total    38074459
# 2022_Total    46318379
# Name: RSC, dtype: int64

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['RSC']], x=x, y="RSC", title = 'RSC Annual Breakdown')
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="7d4bddce-e702-4349-aee7-5eab235fcfa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d4bddce-e702-4349-aee7-5eab235fcfa7")) {                    Plotly.newPlot(                        "7d4bddce-e702-4349-aee7-5eab235fcfa7",                        [{"hovertemplate":"Month=%{x}<br>RSC=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","201
# ...

# %%
df_row['RSC'].plot(kind="bar", title="Annual breakdown of RSC", figsize=(12,10))


plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
df_row[['RSC_LB','RSC_SB']].plot(kind="bar", 
                                 title="RSC Scale",
                                   stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'RSC Scale'}, xlabel='Month'>

# %% [markdown]
# ### FLG

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['FLG']], x=x, y="FLG")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="0dbe52de-1013-4ce4-9498-ee412f163855" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dbe52de-1013-4ce4-9498-ee412f163855")) {                    Plotly.newPlot(                        "0dbe52de-1013-4ce4-9498-ee412f163855",                        [{"hovertemplate":"Month=%{x}<br>FLG=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","201
# ...

# %% [markdown]
# ### HGS

# %%
df_row['HGS'].plot(kind="line", title="Annual breakdown of HGS", figsize=(12,8))
#looking at the specific column and visualising the annual breakdown

plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
df_row[['HGS_LB','HGS_SB']].plot(kind="bar", 
                                 title="HGS Scale",
                                   stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'HGS Scale'}, xlabel='Month'>

# %% [markdown]
# ### FL

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['FL']], x=x, y="FL")
fig.show()
# Out:
# <div>                            <div id="e896fc5f-4bef-481a-9f2a-a9aabcdbdacb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e896fc5f-4bef-481a-9f2a-a9aabcdbdacb")) {                    Plotly.newPlot(                        "e896fc5f-4bef-481a-9f2a-a9aabcdbdacb",                        [{"hovertemplate":"Month=%{x}<br>FL=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","2017
# ...

# %% [markdown]
# ### EHA

# %%
#df_row['EHA']

# %%
df_row['EHA'].plot(kind="bar", title="Annual breakdown of EHA", figsize=(10,8))
#looking at the specific column and visualising the annual breakdown

plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")
# Out:
# Text(0, 0.5, 'Amount in thousands')

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['EHA']], x=x, y="EHA")
fig.show()
# Out:
# <div>                            <div id="08c5f06b-4bc0-4713-b05c-138dbd2bcc60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08c5f06b-4bc0-4713-b05c-138dbd2bcc60")) {                    Plotly.newPlot(                        "08c5f06b-4bc0-4713-b05c-138dbd2bcc60",                        [{"hovertemplate":"Month=%{x}<br>EHA=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","201
# ...

# %% [markdown]
# ### HPG

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['HPG']], x=x, y="HPG")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="716e81db-0941-4887-b6c0-ac8c35335f56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("716e81db-0941-4887-b6c0-ac8c35335f56")) {                    Plotly.newPlot(                        "716e81db-0941-4887-b6c0-ac8c35335f56",                        [{"hovertemplate":"Month=%{x}<br>HPG=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","201
# ...

# %% [markdown]
# ### AVaM

# %%
#df_row['AVaM']

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['AVaM']], x=x, y="AVaM")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="3de8aec3-aab4-4543-a01e-85afc2e86898" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3de8aec3-aab4-4543-a01e-85afc2e86898")) {                    Plotly.newPlot(                        "3de8aec3-aab4-4543-a01e-85afc2e86898",                        [{"hovertemplate":"Month=%{x}<br>AVaM=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","20
# ...

# %% [markdown]
# ### ONFS

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['ONFS']], x=x, y="ONFS")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="c5d7f58b-a1d7-49e5-8518-0466393946a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5d7f58b-a1d7-49e5-8518-0466393946a7")) {                    Plotly.newPlot(                        "c5d7f58b-a1d7-49e5-8518-0466393946a7",                        [{"hovertemplate":"Month=%{x}<br>ONFS=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","20
# ...

# %%
df_row[['ONFS_LB','ONFS_SB']]
# Out:
#              ONFS_LB   ONFS_SB
# Month
# 1996_Total   9392863  22279248
# 1997_Total  10461142  21336054
# 1998_Total  10973784  21815767
# 1999_Total  12093160  21190991
# 2000_Total  13447978  20478644
# 2001_Total  14762444  20518185
# 2002_Total  16413621  22227400
# 2003_Total  17524970  20985424
# 2004_Total  18885124  22200067
# 2005_Total  18902072  22369494
# 2006_Total  19729936  21075869
# 2007_Total  20298434  21474752
# 2008_Total  21691121  23005769
# 2009_Total  20850077  21622889
# 2010_Total  21655685  21759469
# 2011_Total  22443031  21279352
# 2012_Total  22687336  21262223
# 2013_Total  23475822  21705353
# 2014_Total  25955433  23339107
# 2015_Total  26451893  21236224
# 2016_Total  27029849  23587592
# 2017_Total  28339478  23954155
# 2018_Total  28764923  25332902
# 2019_Total  30281274  26490023
# 2020_Total  25657789  26019705
# 2021_Total  30049062  28975105
# 2022_Total  35177719  29387028

# %%
26019705-25657789
# Out:
# 361916

# %%
df_row[['ONFS_LB','ONFS_SB']].plot(kind="bar", 
                                 title="ONFS Large vs Small Scale Businesses",
                                   stacked = True, figsize=(12,10))
# Out:
# <Axes: title={'center': 'ONFS Large vs Small Scale Businesses'}, xlabel='Month'>

# %% [markdown]
# ### OR_PM

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['OR_PM']], x=x, y="OR_PM")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="33becd14-9154-4be3-a60d-2eff6afdf872" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33becd14-9154-4be3-a60d-2eff6afdf872")) {                    Plotly.newPlot(                        "33becd14-9154-4be3-a60d-2eff6afdf872",                        [{"hovertemplate":"Month=%{x}<br>OR_PM=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","2
# ...

# %% [markdown]
# ### OR_BN

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['OR_BN']], x=x, y="OR_BN")
fig.show()
#looking at the specific column and visualising the annual breakdown
# Out:
# <div>                            <div id="3862fa29-8efb-4633-b61a-629a44758fa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3862fa29-8efb-4633-b61a-629a44758fa6")) {                    Plotly.newPlot(                        "3862fa29-8efb-4633-b61a-629a44758fa6",                        [{"hovertemplate":"Month=%{x}<br>OR_BN=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["1996_Total","1997_Total","1998_Total","1999_Total","2000_Total","2001_Total","2002_Total","2003_Total","2004_Total","2005_Total","2006_Total","2007_Total","2008_Total","2009_Total","2010_Total","2011_Total","2012_Total","2013_Total","2014_Total","2015_Total","2016_Total","2
# ...

# %% [markdown]
# ### OR_FC

# %%
df_row['OR_FC'].plot(kind="line", title="Annual breakdown of OR_FC", figsize=(12,8))


plt.style.use('bmh')

plt.xlabel("Year")
plt.ylabel("Amount in thousands")

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['OR_FC']], x=x, y="OR_FC")
fig.show()

# %% [markdown]
# ### OR_CT

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['OR_CT']], x=x, y="OR_CT")
fig.show()

# %% [markdown]
# ### OR_SSNEC

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['OR_SSNEC']], x=x, y="OR_SSNEC")
fig.show()

# %% [markdown]
# ### NSR

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['NSR']], x=x, y="NSR")
fig.show()
#looking at the specific column and visualising the annual breakdown

# %%
df_row[['NSR_LB','NSR_SB']].plot(kind="bar", 
                                 title="NSR Scale",
                                   stacked = True, figsize=(12,10))

# %% [markdown]
# ### NS_MOH

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['NS_MOH']], x=x, y="NS_MOH")
fig.show()

# %% [markdown]
# ### NS_EMOH

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['NS_EMOH']], x=x, y="NS_EMOH")
fig.show()

# %% [markdown]
# ### AF

# %%
import plotly.express as px

x = df_row.index
fig = px.scatter(df_row[['AF']], x=x, y="AF")
fig.show()

# %% [markdown]
# ## Prediction - Next 5 Years

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
df_row['RIA']
# Out:
# Month
# 1996_Total    205963231
# 1997_Total    213143997
# 1998_Total    220404608
# 1999_Total    227024642
# 2000_Total    237864899
# 2001_Total    248311974
# 2002_Total    263302576
# 2003_Total    265334840
# 2004_Total    277849341
# 2005_Total    281450387
# 2006_Total    292109661
# 2007_Total    303621212
# 2008_Total    321177892
# 2009_Total    317657969
# 2010_Total    326241653
# 2011_Total    343158857
# 2012_Total    351048767
# 2013_Total    360107179
# 2014_Total    378053188
# 2015_Total    374817465
# 2016_Total    387696088
# 2017_Total    405780927
# 2018_Total    423709363
# 2019_Total    439600484
# 2020_Total    436741512
# 2021_Total    464163552
# 2022_Total    495667433
# Name: RIA, dtype: int64

# %%
x = df_row.index
y = df_row.iloc[:, 2].values.reshape(-1, 1)

# %% [markdown]
# model = LinearRegression().fit(x, y)
# y_pred = model.predict([[2023]])
# y_pred
